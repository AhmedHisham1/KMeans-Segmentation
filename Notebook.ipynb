# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
from utils import kmeans

# %matplotlib inline

# %%
original_img = cv2.imread('images/colors.jpg')
original_img = cv2.cvtColor(original_img, cv2.COLOR_BGR2RGB)

print(original_img.shape)
img = np.reshape(original_img, (-1,3))
img = img/255
print(img.shape)
centroids, pixel_type = kmeans(img, K=3, iters=3)
# Out:
# (310, 620, 3)
# (192200, 3)
# init centeriods:
#  [[0.99215686 0.39215686 0.4       ]
#  [0.50196078 0.80784314 0.95686275]
#  [0.99215686 0.39215686 0.4       ]]
# A centroid was assigned no pixel values, mean:  [nan nan nan]
# re-initializing this centroid randomly
# C:\ProgramData\Anaconda3\envs\tf_detection\lib\site-packages\numpy\core\fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\ProgramData\Anaconda3\envs\tf_detection\lib\site-packages\numpy\core\_methods.py:163: RuntimeWarning: invalid value encountered in true_divide
#   ret, rcount, out=ret, casting='unsafe', subok=False)

# %%
print(centroids)
segmented_img = centroids[pixel_type.flatten()]
segmented_img = segmented_img.reshape(np.array(original_img).shape)

plt.figure()
plt.subplot(1,2,1)
plt.imshow(original_img)
plt.subplot(1,2,2)
plt.imshow(segmented_img)
# Out:
# [[0.99200888 0.39215686 0.39983352]
#  [0.50192234 0.80790081 0.95676663]
#  [0.39215686 0.98823529 0.41960784]]

# %%
original_img = cv2.imread('images/colors2.jpg')
original_img = cv2.cvtColor(original_img, cv2.COLOR_BGR2RGB)

print(original_img.shape)
img = np.reshape(original_img, (-1,3))
img = img/255
print(img.shape)
centroids, pixel_type = kmeans(img, K=4, iters=5)
# Out:
# (249, 251, 3)
# (62499, 3)
# init centeriods:
#  [[0.99607843 0.99607843 0.99607843]
#  [0.00392157 0.00392157 1.        ]
#  [1.         1.         0.00392157]
#  [0.99607843 0.99607843 0.99607843]]
# A centroid was assigned no pixel values, mean:  [nan nan nan]
# re-initializing this centroid randomly

# %%
print(centroids)
segmented_img = centroids[pixel_type.flatten()]
segmented_img = segmented_img.reshape(np.array(original_img).shape)

plt.figure()
plt.subplot(1,2,1)
plt.imshow(original_img)
plt.subplot(1,2,2)
plt.imshow(segmented_img)
# Out:
# [[0.98972831 0.98536192 0.97902183]
#  [0.01652668 0.0108265  0.9794088 ]
#  [0.99556768 0.99477359 0.02100738]
#  [0.98414687 0.01059035 0.01782598]]

# %%
original_img = cv2.imread('images/myself.jpg')
original_img = cv2.cvtColor(original_img, cv2.COLOR_BGR2RGB)

print(original_img.shape)
img = np.reshape(original_img, (-1,3))
img = img/255
print(img.shape)
centroids, pixel_type = kmeans(img, K=8, iters=10)
# Out:
# (1344, 600, 3)
# (806400, 3)
# init centeriods:
#  [[0.51372549 0.54509804 0.59607843]
#  [0.37647059 0.29019608 0.23529412]
#  [0.20392157 0.16470588 0.16078431]
#  [0.83529412 0.85098039 0.74509804]
#  [0.19607843 0.21176471 0.15686275]
#  [0.3372549  0.27843137 0.19607843]
#  [0.49803922 0.14509804 0.10196078]
#  [0.99607843 0.99607843 0.99607843]]

# %%
print(centroids)
segmented_img = centroids[pixel_type.flatten()]
segmented_img = segmented_img.reshape(np.array(original_img).shape)

plt.figure(figsize=(10,10))
plt.subplot(1,2,1)
plt.imshow(original_img)
plt.subplot(1,2,2)
plt.imshow(segmented_img)
# Out:
# [[0.62128585 0.60393792 0.48712558]
#  [0.49982432 0.44465582 0.36678249]
#  [0.12671866 0.1483122  0.14723108]
#  [0.7695156  0.77752047 0.64683507]
#  [0.23605971 0.23644744 0.21616512]
#  [0.33151067 0.31347852 0.29563896]
#  [0.48942242 0.08034524 0.09170521]
#  [0.94012406 0.93957418 0.87201478]]

# %%
original_img = cv2.imread('images/myself2.png')
original_img = cv2.cvtColor(original_img, cv2.COLOR_BGR2RGB)

print(original_img.shape)
img = np.reshape(original_img, (-1,3))
img = img/255
print(img.shape)
centroids, pixel_type = kmeans(img, K=8, iters=10)
# Out:
# (1274, 955, 3)
# (1216670, 3)
# init centeriods:
#  [[0.30980392 0.1372549  0.12941176]
#  [0.91372549 0.65490196 0.32156863]
#  [0.58431373 0.41568627 0.23921569]
#  [0.21568627 0.10588235 0.10196078]
#  [0.09803922 0.0745098  0.08235294]
#  [0.23137255 0.18431373 0.1372549 ]
#  [0.47843137 0.29803922 0.16470588]
#  [0.18431373 0.16470588 0.16862745]]

# %%
print(centroids)
segmented_img = centroids[pixel_type.flatten()]
segmented_img = segmented_img.reshape(np.array(original_img).shape)

plt.figure(figsize=(10,10))
plt.subplot(1,2,1)
plt.imshow(original_img)
plt.subplot(1,2,2)
plt.imshow(segmented_img)
# Out:
# [[0.40076927 0.26988138 0.18953818]
#  [0.8167863  0.83734755 0.89560049]
#  [0.64003065 0.5568883  0.44868784]
#  [0.22279347 0.14189179 0.12489452]
#  [0.11823646 0.09707726 0.09196509]
#  [0.27909452 0.21381596 0.17837281]
#  [0.50679462 0.40132971 0.28414903]
#  [0.31464751 0.31929173 0.3738858 ]]
